# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000,high = 90.000,size = 2000)
lngs = np.random.uniform(low = -180.000,high = 180.000,size = 2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 780

# %%
#Import the requests library
import requests

#import the API key
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#create a empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval   ")
print("----------------------------")

#Create counter
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i,city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url +"&q=" + city.replace(" ","+")
    
    #Log the URL, record, set number and the city
    print(f"Processing Record {record_count} of Set {set_count}|{city}")
    # Add 1 to the record count
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
pass
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1|mataura
# Processing Record 2 of Set 1|quelimane
# Processing Record 3 of Set 1|asfi
# Processing Record 4 of Set 1|bethel
# Processing Record 5 of Set 1|quatre cocos
# Processing Record 6 of Set 1|new norfolk
# Processing Record 7 of Set 1|albany
# Processing Record 8 of Set 1|ushuaia
# Processing Record 9 of Set 1|khatanga
# Processing Record 10 of Set 1|matara
# Processing Record 11 of Set 1|bajil
# Processing Record 12 of Set 1|omboue
# Processing Record 13 of Set 1|caravelas
# Processing Record 14 of Set 1|stromness
# Processing Record 15 of Set 1|punta arenas
# Processing Record 16 of Set 1|yellowknife
# Processing Record 17 of Set 1|petropavlovsk-kamchatskiy
# Processing Record 18 of Set 1|hermanus
# Processing Record 19 of Set 1|nizhniy kuranakh
# Processing Record 20 of Set 1|whyalla
# Processing Record 21 of Set 1|bonavista
# Processing Record 22 of Set 1|thompson
# Processing Record 23 of Set 1|rikitea
# Processing Record 24 of Set 1|balikpapan
# Processing Record 25 of Set 1|bluff
# Processing Record 26 of Set 1|batticaloa
# Processing Record 27 of Set 1|coolum beach
# Processing Record 28 of Set 1|grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 1|hede
# Processing Record 30 of Set 1|okato
# Processing Record 31 of Set 1|castro
# Processing Record 32 of Set 1|taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1|siteki
# Processing Record 34 of Set 1|kaitangata
# Processing Record 35 of Set 1|busselton
# Processing Record 36 of Set 1|kaeo
# Processing Record 37 of Set 1|dikson
# Processing Record 38 of Set 1|blagoveshchenka
# Processing Record 39 of Set 1|xingyi
# Processing Record 40 of Set 1|leningradskiy
# Processing Record 41 of Set 1|lompoc
# Processing Record 42 of Set 1|bam
# Processing Record 43 of Set 1|faanui
# Processing Record 44 of Set 1|farah
# Processing Record 45 of Set 1|meulaboh
# Processing Record 46 of Set 1|longyearbyen
# Processing Record 47 of Set 1|dingle
# Processing Record 48 of Set 1|greymouth
# Processing Record 49 of Set 1|khonuu
# City not found. Skipping...
# Processing Record 50 of Set 1|qaanaaq
# Processing Record 1 of Set 2|saint-philippe
# Processing Record 2 of Set 2|nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 2|east london
# Processing Record 4 of Set 2|yarada
# Processing Record 5 of Set 2|dehloran
# Processing Record 6 of Set 2|pimentel
# Processing Record 7 of Set 2|cao bang
# Processing Record 8 of Set 2|gwadar
# Processing Record 9 of Set 2|ahipara
# Processing Record 10 of Set 2|bandarbeyla
# Processing Record 11 of Set 2|hilo
# Processing Record 12 of Set 2|ribeira grande
# Processing Record 13 of Set 2|cimarron hills
# Processing Record 14 of Set 2|barrow
# Processing Record 15 of Set 2|terney
# Processing Record 16 of Set 2|la macarena
# Processing Record 17 of Set 2|ruwi
# Processing Record 18 of Set 2|belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2|kapaa
# Processing Record 20 of Set 2|portree
# Processing Record 21 of Set 2|luderitz
# Processing Record 22 of Set 2|peniche
# Processing Record 23 of Set 2|thinadhoo
# Processing Record 24 of Set 2|georgetown
# Processing Record 25 of Set 2|puerto ayora
# Processing Record 26 of Set 2|bud
# Processing Record 27 of Set 2|tarrafal
# Processing Record 28 of Set 2|palu
# Processing Record 29 of Set 2|evensk
# Processing Record 30 of Set 2|barawe
# City not found. Skipping...
# Processing Record 31 of Set 2|itarema
# Processing Record 32 of Set 2|port alfred
# Processing Record 33 of Set 2|saint-francois
# Processing Record 34 of Set 2|eydhafushi
# Processing Record 35 of Set 2|kyaikkami
# Processing Record 36 of Set 2|lorengau
# Processing Record 37 of Set 2|west wendover
# Processing Record 38 of Set 2|mitsamiouli
# Processing Record 39 of Set 2|bantul
# Processing Record 40 of Set 2|troyes
# Processing Record 41 of Set 2|komsomolskiy
# Processing Record 42 of Set 2|jamestown
# Processing Record 43 of Set 2|amazar
# Processing Record 44 of Set 2|butaritari
# Processing Record 45 of Set 2|illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2|narsaq
# Processing Record 47 of Set 2|copperas cove
# Processing Record 48 of Set 2|chuy
# Processing Record 49 of Set 2|warqla
# City not found. Skipping...
# Processing Record 50 of Set 2|kirakira
# Processing Record 1 of Set 3|sao filipe
# Processing Record 2 of Set 3|airai
# Processing Record 3 of Set 3|svobodnyy
# Processing Record 4 of Set 3|charters towers
# Processing Record 5 of Set 3|sitka
# Processing Record 6 of Set 3|shache
# Processing Record 7 of Set 3|mula
# Processing Record 8 of Set 3|fort nelson
# Processing Record 9 of Set 3|hambantota
# Processing Record 10 of Set 3|chokurdakh
# Processing Record 11 of Set 3|nikolskoye
# Processing Record 12 of Set 3|touros
# Processing Record 13 of Set 3|tezu
# Processing Record 14 of Set 3|provideniya
# Processing Record 15 of Set 3|yiyang
# Processing Record 16 of Set 3|salalah
# Processing Record 17 of Set 3|padang
# Processing Record 18 of Set 3|goderich
# Processing Record 19 of Set 3|atar
# Processing Record 20 of Set 3|kasongo-lunda
# Processing Record 21 of Set 3|yabelo
# Processing Record 22 of Set 3|cape town
# Processing Record 23 of Set 3|victoria
# Processing Record 24 of Set 3|katsuura
# Processing Record 25 of Set 3|mehamn
# Processing Record 26 of Set 3|nadvoitsy
# Processing Record 27 of Set 3|nema
# Processing Record 28 of Set 3|cabedelo
# Processing Record 29 of Set 3|tasiilaq
# Processing Record 30 of Set 3|clyde river
# Processing Record 31 of Set 3|puerto del rosario
# Processing Record 32 of Set 3|carnarvon
# Processing Record 33 of Set 3|sladkovo
# Processing Record 34 of Set 3|talnakh
# Processing Record 35 of Set 3|hobart
# Processing Record 36 of Set 3|villa guerrero
# Processing Record 37 of Set 3|revelstoke
# Processing Record 38 of Set 3|paamiut
# Processing Record 39 of Set 3|koutsouras
# Processing Record 40 of Set 3|abu samrah
# Processing Record 41 of Set 3|yulara
# Processing Record 42 of Set 3|bambous virieux
# Processing Record 43 of Set 3|booue
# Processing Record 44 of Set 3|karangampel
# Processing Record 45 of Set 3|talakan
# Processing Record 46 of Set 3|tessalit
# Processing Record 47 of Set 3|dukat
# Processing Record 48 of Set 3|fishers
# Processing Record 49 of Set 3|boke
# Processing Record 50 of Set 3|iqaluit
# Processing Record 1 of Set 4|halalo
# City not found. Skipping...
# Processing Record 2 of Set 4|vila velha
# Processing Record 3 of Set 4|shieli
# Processing Record 4 of Set 4|mar del plata
# Processing Record 5 of Set 4|ballina
# Processing Record 6 of Set 4|anakapalle
# Processing Record 7 of Set 4|tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 4|campbellford
# Processing Record 9 of Set 4|pangnirtung
# Processing Record 10 of Set 4|reidsville
# Processing Record 11 of Set 4|roebourne
# Processing Record 12 of Set 4|tucuma
# Processing Record 13 of Set 4|simi
# Processing Record 14 of Set 4|ponta do sol
# Processing Record 15 of Set 4|mao
# Processing Record 16 of Set 4|pevek
# Processing Record 17 of Set 4|atuona
# Processing Record 18 of Set 4|baoning
# Processing Record 19 of Set 4|qalyub
# Processing Record 20 of Set 4|northview
# Processing Record 21 of Set 4|hithadhoo
# Processing Record 22 of Set 4|buraydah
# Processing Record 23 of Set 4|dhenkanal
# Processing Record 24 of Set 4|bohuslav
# Processing Record 25 of Set 4|seabra
# Processing Record 26 of Set 4|poum
# Processing Record 27 of Set 4|tungkang
# City not found. Skipping...
# Processing Record 28 of Set 4|seoul
# Processing Record 29 of Set 4|alofi
# Processing Record 30 of Set 4|yanan
# City not found. Skipping...
# Processing Record 31 of Set 4|avarua
# Processing Record 32 of Set 4|kaohsiung
# Processing Record 33 of Set 4|saiha
# Processing Record 34 of Set 4|esperance
# Processing Record 35 of Set 4|ilulissat
# Processing Record 36 of Set 4|iguape
# Processing Record 37 of Set 4|saleaula
# City not found. Skipping...
# Processing Record 38 of Set 4|camacha
# Processing Record 39 of Set 4|puerto lleras
# Processing Record 40 of Set 4|palmer
# Processing Record 41 of Set 4|northam
# Processing Record 42 of Set 4|nyrob
# Processing Record 43 of Set 4|weatherford
# Processing Record 44 of Set 4|haines junction
# Processing Record 45 of Set 4|moron
# Processing Record 46 of Set 4|taseyevo
# Processing Record 47 of Set 4|gaomi
# Processing Record 48 of Set 4|praya
# Processing Record 49 of Set 4|orgovany
# Processing Record 50 of Set 4|khormuj
# City not found. Skipping...
# Processing Record 1 of Set 5|sorland
# Processing Record 2 of Set 5|vanimo
# Processing Record 3 of Set 5|fortuna
# Processing Record 4 of Set 5|baykit
# Processing Record 5 of Set 5|dunedin
# Processing Record 6 of Set 5|port elizabeth
# Processing Record 7 of Set 5|grindavik
# Processing Record 8 of Set 5|bredasdorp
# Processing Record 9 of Set 5|tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5|vuktyl
# Processing Record 11 of Set 5|karamea
# City not found. Skipping...
# Processing Record 12 of Set 5|kudahuvadhoo
# Processing Record 13 of Set 5|saskylakh
# Processing Record 14 of Set 5|tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 5|tromso
# Processing Record 16 of Set 5|hasaki
# Processing Record 17 of Set 5|batemans bay
# Processing Record 18 of Set 5|kruisfontein
# Processing Record 19 of Set 5|fort saint james
# Processing Record 20 of Set 5|guerrero negro
# Processing Record 21 of Set 5|gurskoye
# City not found. Skipping...
# Processing Record 22 of Set 5|vodyane
# Processing Record 23 of Set 5|bat yam
# Processing Record 24 of Set 5|lebu
# Processing Record 25 of Set 5|praia da vitoria
# Processing Record 26 of Set 5|loa janan
# Processing Record 27 of Set 5|marcona
# City not found. Skipping...
# Processing Record 28 of Set 5|pacasmayo
# Processing Record 29 of Set 5|tabou
# Processing Record 30 of Set 5|shuyskoye
# Processing Record 31 of Set 5|uige
# Processing Record 32 of Set 5|waipawa
# Processing Record 33 of Set 5|ostrovnoy
# Processing Record 34 of Set 5|vila franca do campo
# Processing Record 35 of Set 5|baculin
# Processing Record 36 of Set 5|vaini
# Processing Record 37 of Set 5|kavaratti
# Processing Record 38 of Set 5|husavik
# Processing Record 39 of Set 5|acajutla
# Processing Record 40 of Set 5|lasa
# Processing Record 41 of Set 5|barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 5|richards bay
# Processing Record 43 of Set 5|copiapo
# Processing Record 44 of Set 5|chokwe
# Processing Record 45 of Set 5|arraial do cabo
# Processing Record 46 of Set 5|okhotsk
# Processing Record 47 of Set 5|sheltozero
# Processing Record 48 of Set 5|porto novo
# Processing Record 49 of Set 5|tuatapere
# Processing Record 50 of Set 5|brasilia
# Processing Record 1 of Set 6|kuala terengganu
# Processing Record 2 of Set 6|fukue
# Processing Record 3 of Set 6|ola
# Processing Record 4 of Set 6|port blair
# Processing Record 5 of Set 6|tomatlan
# Processing Record 6 of Set 6|cabra
# Processing Record 7 of Set 6|alacranes
# Processing Record 8 of Set 6|newport
# Processing Record 9 of Set 6|louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 6|bengkulu
# Processing Record 11 of Set 6|kamaishi
# Processing Record 12 of Set 6|arrifes
# Processing Record 13 of Set 6|severo-kurilsk
# Processing Record 14 of Set 6|namtsy
# Processing Record 15 of Set 6|tibati
# Processing Record 16 of Set 6|urubicha
# Processing Record 17 of Set 6|tuktoyaktuk
# Processing Record 18 of Set 6|blackwater
# Processing Record 19 of Set 6|dewa
# Processing Record 20 of Set 6|tiksi
# Processing Record 21 of Set 6|ossora
# Processing Record 22 of Set 6|shyroke
# Processing Record 23 of Set 6|mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 6|angoche
# Processing Record 25 of Set 6|zhuhai
# Processing Record 26 of Set 6|puerto escondido
# Processing Record 27 of Set 6|san javier
# Processing Record 28 of Set 6|gondanglegi
# Processing Record 29 of Set 6|saint-pierre
# Processing Record 30 of Set 6|makung
# City not found. Skipping...
# Processing Record 31 of Set 6|ishigaki
# Processing Record 32 of Set 6|mangrol
# Processing Record 33 of Set 6|ivanteyevka
# Processing Record 34 of Set 6|langelsheim
# Processing Record 35 of Set 6|geraldton
# Processing Record 36 of Set 6|lufilufi
# Processing Record 37 of Set 6|sioux lookout
# Processing Record 38 of Set 6|tiarei
# Processing Record 39 of Set 6|liman
# Processing Record 40 of Set 6|colonia
# Processing Record 41 of Set 6|trairi
# Processing Record 42 of Set 6|zhigansk
# Processing Record 43 of Set 6|ravar
# Processing Record 44 of Set 6|cockburn town
# Processing Record 45 of Set 6|dingzhou
# Processing Record 46 of Set 6|hualmay
# Processing Record 47 of Set 6|poco verde
# Processing Record 48 of Set 6|abu dhabi
# Processing Record 49 of Set 6|vestmanna
# Processing Record 50 of Set 6|gornopravdinsk
# Processing Record 1 of Set 7|san cristobal
# Processing Record 2 of Set 7|eureka
# Processing Record 3 of Set 7|batesville
# Processing Record 4 of Set 7|ribeira brava
# Processing Record 5 of Set 7|naze
# Processing Record 6 of Set 7|cidreira
# Processing Record 7 of Set 7|ratnagiri
# Processing Record 8 of Set 7|nanortalik
# Processing Record 9 of Set 7|chifeng
# Processing Record 10 of Set 7|los llanos de aridane
# Processing Record 11 of Set 7|walvis bay
# Processing Record 12 of Set 7|nome
# Processing Record 13 of Set 7|yenagoa
# Processing Record 14 of Set 7|asau
# Processing Record 15 of Set 7|sola
# Processing Record 16 of Set 7|bumba
# Processing Record 17 of Set 7|ornskoldsvik
# Processing Record 18 of Set 7|noumea
# Processing Record 19 of Set 7|anau
# Processing Record 20 of Set 7|tamiahua
# Processing Record 21 of Set 7|bykovo
# Processing Record 22 of Set 7|sault sainte marie
# Processing Record 23 of Set 7|katobu
# Processing Record 24 of Set 7|vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 7|salina
# Processing Record 26 of Set 7|norman wells
# Processing Record 27 of Set 7|bambanglipuro
# Processing Record 28 of Set 7|lodwar
# Processing Record 29 of Set 7|majene
# Processing Record 30 of Set 7|khani
# Processing Record 31 of Set 7|baykalsk
# Processing Record 32 of Set 7|vestmannaeyjar
# Processing Record 33 of Set 7|gori
# Processing Record 34 of Set 7|puerto carreno
# Processing Record 35 of Set 7|puerto gaitan
# Processing Record 36 of Set 7|andevoranto
# City not found. Skipping...
# Processing Record 37 of Set 7|fort-shevchenko
# Processing Record 38 of Set 7|mandera
# Processing Record 39 of Set 7|upernavik
# Processing Record 40 of Set 7|sembakung
# Processing Record 41 of Set 7|prince rupert
# Processing Record 42 of Set 7|ayagoz
# Processing Record 43 of Set 7|constitucion
# Processing Record 44 of Set 7|selu
# Processing Record 45 of Set 7|beni mazar
# Processing Record 46 of Set 7|panixtlahuaca
# City not found. Skipping...
# Processing Record 47 of Set 7|christchurch
# Processing Record 48 of Set 7|kaili
# Processing Record 49 of Set 7|coahuayana
# Processing Record 50 of Set 7|hofn
# Processing Record 1 of Set 8|sarandi
# Processing Record 2 of Set 8|dubbo
# Processing Record 3 of Set 8|minsk
# Processing Record 4 of Set 8|three hills
# Processing Record 5 of Set 8|codrington
# Processing Record 6 of Set 8|isangel
# Processing Record 7 of Set 8|port augusta
# Processing Record 8 of Set 8|bafra
# Processing Record 9 of Set 8|basco
# Processing Record 10 of Set 8|fredericksburg
# Processing Record 11 of Set 8|agadir
# Processing Record 12 of Set 8|iskateley
# Processing Record 13 of Set 8|cascais
# Processing Record 14 of Set 8|bangolo
# Processing Record 15 of Set 8|port-gentil
# Processing Record 16 of Set 8|mahanoro
# Processing Record 17 of Set 8|zhanaozen
# Processing Record 18 of Set 8|nantucket
# Processing Record 19 of Set 8|artyom
# Processing Record 20 of Set 8|coquimbo
# Processing Record 21 of Set 8|sept-iles
# Processing Record 22 of Set 8|sterling
# Processing Record 23 of Set 8|buctzotz
# Processing Record 24 of Set 8|pacific grove
# Processing Record 25 of Set 8|kimi
# City not found. Skipping...
# Processing Record 26 of Set 8|stephenville
# Processing Record 27 of Set 8|zabol
# Processing Record 28 of Set 8|ust-ishim
# Processing Record 29 of Set 8|saint george
# Processing Record 30 of Set 8|broome
# Processing Record 31 of Set 8|ulladulla
# Processing Record 32 of Set 8|arequipa
# Processing Record 33 of Set 8|balakhninskiy
# Processing Record 34 of Set 8|marmaris
# Processing Record 35 of Set 8|issoudun
# Processing Record 36 of Set 8|rajampet
# Processing Record 37 of Set 8|malwan
# City not found. Skipping...
# Processing Record 38 of Set 8|cheltenham
# Processing Record 39 of Set 8|gamba
# Processing Record 40 of Set 8|djenne
# Processing Record 41 of Set 8|san patricio
# Processing Record 42 of Set 8|mount isa
# Processing Record 43 of Set 8|port lincoln
# Processing Record 44 of Set 8|canitas
# City not found. Skipping...
# Processing Record 45 of Set 8|wiang sa
# Processing Record 46 of Set 8|egvekinot
# Processing Record 47 of Set 8|esna
# Processing Record 48 of Set 8|makakilo city
# Processing Record 49 of Set 8|westlock
# Processing Record 50 of Set 8|attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 9|teguise
# Processing Record 2 of Set 9|luau
# Processing Record 3 of Set 9|nhulunbuy
# Processing Record 4 of Set 9|ocean city
# Processing Record 5 of Set 9|pietarsaari
# Processing Record 6 of Set 9|troitskoye
# Processing Record 7 of Set 9|yomitan
# City not found. Skipping...
# Processing Record 8 of Set 9|sorvag
# City not found. Skipping...
# Processing Record 9 of Set 9|saldanha
# Processing Record 10 of Set 9|lavrentiya
# Processing Record 11 of Set 9|stoyba
# City not found. Skipping...
# Processing Record 12 of Set 9|maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 9|cherskiy
# Processing Record 14 of Set 9|tazovskiy
# Processing Record 15 of Set 9|kuche
# City not found. Skipping...
# Processing Record 16 of Set 9|hamilton
# Processing Record 17 of Set 9|tonekabon
# Processing Record 18 of Set 9|takoradi
# Processing Record 19 of Set 9|watertown
# Processing Record 20 of Set 9|kamenka
# Processing Record 21 of Set 9|rio grande
# Processing Record 22 of Set 9|urumqi
# Processing Record 23 of Set 9|nouadhibou
# Processing Record 24 of Set 9|karatau
# Processing Record 25 of Set 9|rocha
# Processing Record 26 of Set 9|vanavara
# Processing Record 27 of Set 9|wilmington
# Processing Record 28 of Set 9|nioro
# Processing Record 29 of Set 9|mount gambier
# Processing Record 30 of Set 9|kosa
# Processing Record 31 of Set 9|sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 9|astana
# Processing Record 33 of Set 9|sernur
# Processing Record 34 of Set 9|yumen
# Processing Record 35 of Set 9|shar
# Processing Record 36 of Set 9|portel
# Processing Record 37 of Set 9|midland
# Processing Record 38 of Set 9|basar
# Processing Record 39 of Set 9|benguela
# Processing Record 40 of Set 9|baruun-urt
# Processing Record 41 of Set 9|mahebourg
# Processing Record 42 of Set 9|nalut
# Processing Record 43 of Set 9|kavieng
# Processing Record 44 of Set 9|hoquiam
# Processing Record 45 of Set 9|bosansko grahovo
# Processing Record 46 of Set 9|riverton
# Processing Record 47 of Set 9|coldwater
# Processing Record 48 of Set 9|mrirt
# City not found. Skipping...
# Processing Record 49 of Set 9|harper
# Processing Record 50 of Set 9|mahajanga
# Processing Record 1 of Set 10|namatanai
# Processing Record 2 of Set 10|troy
# Processing Record 3 of Set 10|kieta
# Processing Record 4 of Set 10|bathsheba
# Processing Record 5 of Set 10|stornoway
# Processing Record 6 of Set 10|santiago de cuba
# Processing Record 7 of Set 10|maria aurora
# Processing Record 8 of Set 10|yinchuan
# Processing Record 9 of Set 10|amderma
# City not found. Skipping...
# Processing Record 10 of Set 10|valdivia
# Processing Record 11 of Set 10|krivosheino
# Processing Record 12 of Set 10|westport
# Processing Record 13 of Set 10|saint stephen
# Processing Record 14 of Set 10|hammerfest
# Processing Record 15 of Set 10|luena
# Processing Record 16 of Set 10|victor harbor
# Processing Record 17 of Set 10|arona
# Processing Record 18 of Set 10|wajir
# Processing Record 19 of Set 10|kodiak
# Processing Record 20 of Set 10|new albany
# Processing Record 21 of Set 10|lilongwe
# Processing Record 22 of Set 10|mandalgovi
# Processing Record 23 of Set 10|torbay
# Processing Record 24 of Set 10|tshikapa
# Processing Record 25 of Set 10|khasan
# Processing Record 26 of Set 10|tutoia
# Processing Record 27 of Set 10|ulaangom
# Processing Record 28 of Set 10|itoman
# Processing Record 29 of Set 10|sao mateus do maranhao
# Processing Record 30 of Set 10|olinda
# Processing Record 31 of Set 10|galle
# Processing Record 32 of Set 10|casselman
# Processing Record 33 of Set 10|taree
# Processing Record 34 of Set 10|flinders
# Processing Record 35 of Set 10|santa maria
# Processing Record 36 of Set 10|la ronge
# Processing Record 37 of Set 10|novobirilyussy
# Processing Record 38 of Set 10|marovoay
# Processing Record 39 of Set 10|xuddur
# Processing Record 40 of Set 10|cabo san lucas
# Processing Record 41 of Set 10|taksimo
# Processing Record 42 of Set 10|fairbanks
# Processing Record 43 of Set 10|altamira
# Processing Record 44 of Set 10|tual
# Processing Record 45 of Set 10|ukholovo
# Processing Record 46 of Set 10|kholm
# Processing Record 47 of Set 10|linjiang
# Processing Record 48 of Set 10|de aar
# Processing Record 49 of Set 10|kranj
# Processing Record 50 of Set 10|todos santos
# Processing Record 1 of Set 11|gubkinskiy
# Processing Record 2 of Set 11|anzio
# Processing Record 3 of Set 11|phan rang
# City not found. Skipping...
# Processing Record 4 of Set 11|klaksvik
# Processing Record 5 of Set 11|turan
# Processing Record 6 of Set 11|san jeronimo
# Processing Record 7 of Set 11|serenje
# Processing Record 8 of Set 11|sao joao da barra
# Processing Record 9 of Set 11|pata
# Processing Record 10 of Set 11|koboldo
# City not found. Skipping...
# Processing Record 11 of Set 11|vestbygda
# City not found. Skipping...
# Processing Record 12 of Set 11|spirit river
# Processing Record 13 of Set 11|khilok
# Processing Record 14 of Set 11|margate
# Processing Record 15 of Set 11|nam tha
# City not found. Skipping...
# Processing Record 16 of Set 11|igarka
# Processing Record 17 of Set 11|riga
# Processing Record 18 of Set 11|uyuni
# Processing Record 19 of Set 11|vodnany
# Processing Record 20 of Set 11|kayes
# Processing Record 21 of Set 11|tashtagol
# Processing Record 22 of Set 11|ribnica
# Processing Record 23 of Set 11|tymovskoye
# Processing Record 24 of Set 11|kapit
# Processing Record 25 of Set 11|talcahuano
# Processing Record 26 of Set 11|jalu
# Processing Record 27 of Set 11|phanom thuan
# Processing Record 28 of Set 11|uyovu
# Processing Record 29 of Set 11|tagusao
# Processing Record 30 of Set 11|cap-aux-meules
# Processing Record 31 of Set 11|sulangan
# Processing Record 32 of Set 11|requena
# Processing Record 33 of Set 11|jiuquan
# Processing Record 34 of Set 11|katherine
# Processing Record 35 of Set 11|palana
# Processing Record 36 of Set 11|tuburan
# Processing Record 37 of Set 11|virarajendrapet
# Processing Record 38 of Set 11|dwarka
# Processing Record 39 of Set 11|alotau
# City not found. Skipping...
# Processing Record 40 of Set 11|ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 11|cayenne
# Processing Record 42 of Set 11|sao sepe
# Processing Record 43 of Set 11|kyshtovka
# Processing Record 44 of Set 11|srednekolymsk
# Processing Record 45 of Set 11|port moresby
# Processing Record 46 of Set 11|taoudenni
# Processing Record 47 of Set 11|boa vista
# Processing Record 48 of Set 11|southbridge
# Processing Record 49 of Set 11|sistranda
# Processing Record 50 of Set 11|jaque
# Processing Record 1 of Set 12|along
# Processing Record 2 of Set 12|port hedland
# Processing Record 3 of Set 12|samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 12|santa fe
# Processing Record 5 of Set 12|sol-iletsk
# Processing Record 6 of Set 12|rolla
# Processing Record 7 of Set 12|avera
# Processing Record 8 of Set 12|maine-soroa
# Processing Record 9 of Set 12|kahului
# Processing Record 10 of Set 12|adrar
# Processing Record 11 of Set 12|cam ranh
# Processing Record 12 of Set 12|vostok
# Processing Record 13 of Set 12|umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 12|lixourion
# Processing Record 15 of Set 12|ndende
# Processing Record 16 of Set 12|san remigio
# Processing Record 17 of Set 12|faya
# Processing Record 18 of Set 12|bowen
# Processing Record 19 of Set 12|kankaanpaa
# Processing Record 20 of Set 12|shaoguan
# Processing Record 21 of Set 12|mbaiki
# Processing Record 22 of Set 12|marseille
# Processing Record 23 of Set 12|palermo
# Processing Record 24 of Set 12|san vicente de canete
# Processing Record 25 of Set 12|malinovka
# Processing Record 26 of Set 12|abaetetuba
# Processing Record 27 of Set 12|flin flon
# Processing Record 28 of Set 12|ozgon
# City not found. Skipping...
# Processing Record 29 of Set 12|kasempa
# Processing Record 30 of Set 12|chumikan
# Processing Record 31 of Set 12|bossembele
# City not found. Skipping...
# Processing Record 32 of Set 12|san juan
# Processing Record 33 of Set 12|haian
# Processing Record 34 of Set 12|aykhal
# Processing Record 35 of Set 12|florida
# Processing Record 36 of Set 12|palora
# Processing Record 37 of Set 12|dinsor
# City not found. Skipping...
# Processing Record 38 of Set 12|udachnyy
# Processing Record 39 of Set 12|galesong
# Processing Record 40 of Set 12|lagoa
# Processing Record 41 of Set 12|galveston
# Processing Record 42 of Set 12|progreso
# Processing Record 43 of Set 12|jiroft
# City not found. Skipping...
# Processing Record 44 of Set 12|ihiala
# Processing Record 45 of Set 12|bereslavka
# Processing Record 46 of Set 12|mayo
# Processing Record 47 of Set 12|paita
# Processing Record 48 of Set 12|saint anthony
# Processing Record 49 of Set 12|fountain hills
# Processing Record 50 of Set 12|nakonde
# Processing Record 1 of Set 13|el alto
# Processing Record 2 of Set 13|george
# Processing Record 3 of Set 13|killybegs
# Processing Record 4 of Set 13|shimoda
# Processing Record 5 of Set 13|aklavik
# Processing Record 6 of Set 13|ksenyevka
# City not found. Skipping...
# Processing Record 7 of Set 13|winnemucca
# Processing Record 8 of Set 13|santo antonio do ica
# Processing Record 9 of Set 13|ca mau
# Processing Record 10 of Set 13|kununurra
# Processing Record 11 of Set 13|jiaozuo
# Processing Record 12 of Set 13|nipawin
# Processing Record 13 of Set 13|ortakoy
# Processing Record 14 of Set 13|bukama
# Processing Record 15 of Set 13|qaqortoq
# Processing Record 16 of Set 13|san policarpo
# Processing Record 17 of Set 13|huarmey
# Processing Record 18 of Set 13|muskogee
# Processing Record 19 of Set 13|taltal
# Processing Record 20 of Set 13|inirida
# Processing Record 21 of Set 13|romanovka
# Processing Record 22 of Set 13|prince george
# Processing Record 23 of Set 13|kawalu
# Processing Record 24 of Set 13|najran
# Processing Record 25 of Set 13|sarangani
# Processing Record 26 of Set 13|pundaguitan
# Processing Record 27 of Set 13|pulandian
# Processing Record 28 of Set 13|lypnyazhka
# Processing Record 29 of Set 13|kirovo-chepetsk
# Processing Record 30 of Set 13|ancud
# Processing Record 31 of Set 13|tapaua
# City not found. Skipping...
# Processing Record 32 of Set 13|vardo
# Processing Record 33 of Set 13|kibaya
# Processing Record 34 of Set 13|saint-louis
# Processing Record 35 of Set 13|montrose
# Processing Record 36 of Set 13|tortoli
# Processing Record 37 of Set 13|rungata
# City not found. Skipping...
# Processing Record 38 of Set 13|nivala
# Processing Record 39 of Set 13|mercedes
# Processing Record 40 of Set 13|arua
# Processing Record 41 of Set 13|misasi
# Processing Record 42 of Set 13|labuhan
# Processing Record 43 of Set 13|vezirkopru
# Processing Record 44 of Set 13|skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 13|inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 13|olafsvik
# Processing Record 47 of Set 13|yar-sale
# Processing Record 48 of Set 13|karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 13|shelburne
# Processing Record 50 of Set 13|ulverstone
# Processing Record 1 of Set 14|russell
# Processing Record 2 of Set 14|savalou
# Processing Record 3 of Set 14|odweyne
# Processing Record 4 of Set 14|nuuk
# Processing Record 5 of Set 14|lang suan
# Processing Record 6 of Set 14|ouallam
# Processing Record 7 of Set 14|labrea
# Processing Record 8 of Set 14|srisailam
# Processing Record 9 of Set 14|dawson creek
# Processing Record 10 of Set 14|shujalpur
# Processing Record 11 of Set 14|port angeles
# Processing Record 12 of Set 14|muisne
# Processing Record 13 of Set 14|xining
# Processing Record 14 of Set 14|mandal
# Processing Record 15 of Set 14|azimur
# City not found. Skipping...
# Processing Record 16 of Set 14|warri
# Processing Record 17 of Set 14|cabras
# Processing Record 18 of Set 14|aksu
# Processing Record 19 of Set 14|baiao
# Processing Record 20 of Set 14|pemba
# Processing Record 21 of Set 14|armacao dos buzios
# City not found. Skipping...
# Processing Record 22 of Set 14|zheleznodorozhnyy
# Processing Record 23 of Set 14|tabuk
# Processing Record 24 of Set 14|avallon
# Processing Record 25 of Set 14|souillac
# Processing Record 26 of Set 14|urdzhar
# City not found. Skipping...
# Processing Record 27 of Set 14|verkhnevilyuysk
# Processing Record 28 of Set 14|gorontalo
# Processing Record 29 of Set 14|swift current
# Processing Record 30 of Set 14|dedza
# Processing Record 31 of Set 14|korop
# Processing Record 32 of Set 14|znamenskoye
# Processing Record 33 of Set 14|venado tuerto
# Processing Record 34 of Set 14|kipini
# Processing Record 35 of Set 14|comodoro rivadavia
# Processing Record 36 of Set 14|rize
# Processing Record 37 of Set 14|formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 14|kegayli
# City not found. Skipping...
# Processing Record 39 of Set 14|prieska
# Processing Record 40 of Set 14|sao jose da coroa grande
# Processing Record 41 of Set 14|doka
# Processing Record 42 of Set 14|krutikha
# Processing Record 43 of Set 14|man
# Processing Record 44 of Set 14|hohhot
# Processing Record 45 of Set 14|madarounfa
# Processing Record 46 of Set 14|berlevag
# Processing Record 47 of Set 14|alice springs
# Processing Record 48 of Set 14|camrose
# Processing Record 49 of Set 14|purulha
# Processing Record 50 of Set 14|dzhebariki-khaya
# Processing Record 1 of Set 15|karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 15|bontang
# Processing Record 3 of Set 15|dutlwe
# Processing Record 4 of Set 15|matane
# Processing Record 5 of Set 15|chatellerault
# Processing Record 6 of Set 15|labytnangi
# Processing Record 7 of Set 15|kulhudhuffushi
# Processing Record 8 of Set 15|praia
# Processing Record 9 of Set 15|saint-joseph
# Processing Record 10 of Set 15|khandbari
# Processing Record 11 of Set 15|borogontsy
# Processing Record 12 of Set 15|vancouver
# Processing Record 13 of Set 15|port keats
# Processing Record 14 of Set 15|haag
# Processing Record 15 of Set 15|shibarghan
# City not found. Skipping...
# Processing Record 16 of Set 15|guanica
# Processing Record 17 of Set 15|miraslau
# Processing Record 18 of Set 15|zlobin
# Processing Record 19 of Set 15|dongsheng
# Processing Record 20 of Set 15|sataua
# City not found. Skipping...
# Processing Record 21 of Set 15|beloha
# Processing Record 22 of Set 15|mazatlan
# Processing Record 23 of Set 15|cradock
# Processing Record 24 of Set 15|sabang
# Processing Record 25 of Set 15|sinkat
# City not found. Skipping...
# Processing Record 26 of Set 15|port-cartier
# Processing Record 27 of Set 15|gardan diwal
# City not found. Skipping...
# Processing Record 28 of Set 15|staryy nadym
# Processing Record 29 of Set 15|guia de isora
# Processing Record 30 of Set 15|namibe
# Processing Record 31 of Set 15|anshun
# Processing Record 32 of Set 15|upata
# Processing Record 33 of Set 15|malm
# Processing Record 34 of Set 15|lalomanu
# City not found. Skipping...
# Processing Record 35 of Set 15|amga
# Processing Record 36 of Set 15|grand gaube
# Processing Record 37 of Set 15|chulman
# Processing Record 38 of Set 15|chernyy yar
# Processing Record 39 of Set 15|batagay-alyta
# Processing Record 40 of Set 15|tahe
# Processing Record 41 of Set 15|bereda
# Processing Record 42 of Set 15|deputatskiy
# Processing Record 43 of Set 15|necochea
# Processing Record 44 of Set 15|lensk
# Processing Record 45 of Set 15|tahta
# Processing Record 46 of Set 15|tanout
# Processing Record 47 of Set 15|samusu
# City not found. Skipping...
# Processing Record 48 of Set 15|punta alta
# Processing Record 49 of Set 15|stare mesto
# Processing Record 50 of Set 15|lashio
# Processing Record 1 of Set 16|oussouye
# Processing Record 2 of Set 16|lata
# Processing Record 3 of Set 16|akyab
# Processing Record 4 of Set 16|namanga
# Processing Record 5 of Set 16|vao
# Processing Record 6 of Set 16|drayton valley
# Processing Record 7 of Set 16|trinidad
# Processing Record 8 of Set 16|sinnai
# Processing Record 9 of Set 16|coihaique
# Processing Record 10 of Set 16|bilibino
# Processing Record 11 of Set 16|finschhafen
# Processing Record 12 of Set 16|veraval
# Processing Record 13 of Set 16|ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 16|chernyshevskiy
# Processing Record 15 of Set 16|shentala
# Processing Record 16 of Set 16|khandyga
# Processing Record 17 of Set 16|luan
# Processing Record 18 of Set 16|acapulco
# Processing Record 19 of Set 16|develi
# Processing Record 20 of Set 16|ojinaga
# Processing Record 21 of Set 16|claremore
# Processing Record 22 of Set 16|kutum
# Processing Record 23 of Set 16|gilgit
# Processing Record 24 of Set 16|kenora
# Processing Record 25 of Set 16|singleton
# Processing Record 26 of Set 16|mantua
# Processing Record 27 of Set 16|san andres
# Processing Record 28 of Set 16|ambulu
# Processing Record 29 of Set 16|natal
# Processing Record 30 of Set 16|zeerust
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
# Convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     31.48        97          51
# 1     Quelimane -17.8786   36.8883     76.95        69          40
# 2          Asfi  32.2994   -9.2372     71.91        80          16
# 3        Bethel  41.3712  -73.4140     68.65        82          75
# 4  Quatre Cocos -20.2078   57.7625     71.71        84         100
# 5   New Norfolk -42.7826  147.0587     42.93        84          55
# 6        Albany  42.6001  -73.9662     72.23        66          98
# 7       Ushuaia -54.8000  -68.3000     46.06        76           0
# 8      Khatanga  71.9667  102.5000     64.08        40           7
# 9        Matara   5.9485   80.5353     79.00        88          97
#
#    Wind Speed Country                 Date Current Description
# 0        3.00      NZ  2022-06-12 14:31:34       broken clouds
# 1        9.22      MZ  2022-06-12 14:31:34    scattered clouds
# 2        6.73      MA  2022-06-12 14:31:34          few clouds
# 3       10.36      US  2022-06-12 14:31:35       broken clouds
# 4       16.06      MU  2022-06-12 14:31:35       moderate rain
# 5        3.40      AU  2022-06-12 14:31:36       broken clouds
# 6        1.99      US  2022-06-12 14:27:10     overcast clouds
# 7        0.00      AR  2022-06-12 14:31:36           clear sky
# 8        9.80      RU  2022-06-12 14:31:37           clear sky
# 9        8.50      LK  2022-06-12 14:31:37     overcast clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     31.48        97          51
# 1     Quelimane      MZ -17.8786   36.8883     76.95        69          40
# 2          Asfi      MA  32.2994   -9.2372     71.91        80          16
# 3        Bethel      US  41.3712  -73.4140     68.65        82          75
# 4  Quatre Cocos      MU -20.2078   57.7625     71.71        84         100
# 5   New Norfolk      AU -42.7826  147.0587     42.93        84          55
# 6        Albany      US  42.6001  -73.9662     72.23        66          98
# 7       Ushuaia      AR -54.8000  -68.3000     46.06        76           0
# 8      Khatanga      RU  71.9667  102.5000     64.08        40           7
# 9        Matara      LK   5.9485   80.5353     79.00        88          97
#
#    Wind Speed Current Description
# 0        3.00       broken clouds
# 1        9.22    scattered clouds
# 2        6.73          few clouds
# 3       10.36       broken clouds
# 4       16.06       moderate rain
# 5        3.40       broken clouds
# 6        1.99     overcast clouds
# 7        0.00           clear sky
# 8        9.80           clear sky
# 9        8.50     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
